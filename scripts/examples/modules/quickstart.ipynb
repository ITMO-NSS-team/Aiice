# %%
import imageio
from pprint import pprint
import os
from IPython.display import Image, display

import torch
import torch.nn as nn

# %% [markdown]
# # Quickstart

# %%
from aiice import AIICE

# %% [markdown]
# Let's take a simple persistence model that repeats the last observed frame

# %%
class DummyModel(nn.Module):
    def __init__(self, forecast_len: int):
        super().__init__()
        self.forecast_len = forecast_len

    def forward(self, x):
        # X.shape = [B, pre_history_len, H, W]
        # Y.shape = [B, forecast_len, H, W]
        return x[:, -1:, :, :].repeat(1, self.forecast_len, 1, 1)

model = DummyModel(forecast_len=6)

# %% [markdown]
# AIICE loads the dataset, prepares sliding windows and evaluates the model.

# %%
aiice = AIICE(
    pre_history_len=12,
    forecast_len=6,
    batch_size=4,
    start="2024-01-01",
    end="2024-04-01",
)
# Out:
# mask_data/arctic_seas_inds.csv:   0%|          | 0.00/273 [00:00<?, ?B/s]
# mask_data/seas_mask_IHO.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240101.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240103.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240109.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240118.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240112.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240107.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240116.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240102.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240117.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240111.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240119.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240105.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240108.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240114.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240106.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240115.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240120.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240110.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240113.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240122.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240121.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240130.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240124.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240127.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240123.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240207.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240104.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240208.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240131.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240205.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240126.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240128.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240125.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240201.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240129.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240202.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240210.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240209.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240203.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240204.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240212.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240211.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240206.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240215.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240216.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240218.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240219.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240214.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240213.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240222.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240220.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240221.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240305.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240223.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240308.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240304.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240225.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240217.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240228.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240226.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240229.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240303.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240309.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240307.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240302.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240310.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240311.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240224.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240312.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240227.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240306.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240301.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240314.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240315.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240316.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240313.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240321.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240318.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240320.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240319.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240322.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240326.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240324.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240323.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240328.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240329.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240325.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240330.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240331.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240317.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240327.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]
# global_series/2024/osisaf_20240401.npy:   0%|          | 0.00/747k [00:00<?, ?B/s]

# %%
results = aiice.bench(
    model,
    path="../../../.tmp/quickstart_example"  # optional: saves forecast GIFs
)
# Out:
# Prediction: 100%|████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:05<00:00,  3.77it/s]
# Saving plots: 100%|██████████████████████████████████████████████████████████████████████████████████| 19/19 [00:09<00:00,  2.07it/s]

# %%
pprint(results)
# Out:
# {'bin_accuracy': {'count': 19,
#                   'last': 0.9966069459915161,
#                   'max': 0.9967736005783081,
#                   'mean': 0.9961233358634146,
#                   'min': 0.9953031539916992},
#  'mae': {'count': 19,
#          'last': 0.004773612134158611,
#          'max': 0.0066261193715035915,
#          'mean': 0.00573024761519934,
#          'min': 0.004630558658391237},
#  'mse': {'count': 19,
#          'last': 0.0007545569678768516,
#          'max': 0.0014883286785334349,
#          'mean': 0.0011295564503310935,
#          'min': 0.0007319178548641503},
#  'psnr': {'count': 19,
#           'last': 31.223079681396484,
#           'max': 31.355377197265625,
#           'mean': 29.552193290308903,
#           'min': 28.273012161254883},
#  'rmse': {'count': 19,
#           'last': 0.027469201013445854,
#           'max': 0.03857886418700218,
#           'mean': 0.03345429191463872,
#           'min': 0.02705398015677929},
#  'ssim': {'count': 19,
#           'last': 0.980254054069519,
#           'max': 0.9807162880897522,
#           'mean': 0.9762947873065346,
#           'min': 0.9730460047721863}}

# %%
gif_files = sorted(os.listdir("../../../.tmp/quickstart_example"))
pprint(gif_files)
# Out:
# ['01-02-2024_06-02-2024.gif',
#  '01-03-2024_06-03-2024.gif',
